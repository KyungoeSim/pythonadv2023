# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs

# %%
driver = webdriver.Chrome('chromedriver.exe')
url = 'https://www.genie.co.kr/chart/top200'
driver.get(url)

txt=driver.page_source
html=bs(txt)
print(html)
# Out:
# C:\Users\tlaru\AppData\Local\Temp\ipykernel_6884\1985001747.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# <html class="js flexbox canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers no-applicationcache svg inlinesvg smil svgclippaths" dir="ltr" lang="ko" style=""><head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--[if lte IE 6]><html dir="ltr" class="no-js ie6"><![endif]-->
# <!--[if lte IE 7]><html dir="ltr" class="no-js ie7"><![endif]-->
# <!--[if IE 8]><html dir="ltr" class="no-js ie8"><![endif]-->
# ...

# %%
len(html.select('tr'))
# Out:
# 51

# %%
songs = html.select('tbody > tr')
song = songs[0]

# %%
from pprint import pprint
pprint(song)
# Out:
# <tr class="list" songid="99570005">
# <td class="check"><input class="select-check" title="Ditto" type="checkbox"/></td>
# <td class="number">1
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83325577');return false;"><span class="mask"></span><img alt="NewJeans 'OMG'" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/325/577/83325577_1672649874616_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('99570005');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('99570005','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Ditto</a>
# ...

# %%
title=song.select('a.title')
print(title)
pprint(title)
# Out:
# [<a class="title ellipsis" href="#" onclick="fnPlaySong('99570005','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Ditto</a>]
# [<a class="title ellipsis" href="#" onclick="fnPlaySong('99570005','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Ditto</a>]

# %%
song.select('a.title')[0].text.strip()
# Out:
# 'Ditto'

# %%
from selenium import webdriver          #웹브라우저 컨트롤
from bs4 import BeautifulSoup as bs     #읽어오느 웹페이지 정제
import pandas as pd                     #데이터분석 모듈

driver = webdriver.Chrome('chromedriver.exe')   #버전주의
url = 'https://www.genie.co.kr/chart/top200'
driver.get(url)

txt=driver.page_source                  #이때 읽어온 데이터는 그냥 글자
html=bs(txt)

songs = html.select('tbody>tr')

song_data = []
rank=1

for song in songs:
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text.strip()

    song_data.append(['지니',rank,title,singer])
    rank += 1


url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230228&hh=14&rtm=Y&pg=2'
driver.get(url)

txt=driver.page_source                  #이때 읽어온 데이터는 그냥 글자
html=bs(txt)

songs = html.select('tbody>tr')

for song in songs:
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text.strip()

    song_data.append(['지니',rank,title,singer])
    rank += 1

df=pd.DataFrame(song_data,columns=['서비스','순위','타이틀','가수'])
df
# Out:
# C:\Users\tlaru\AppData\Local\Temp\ipykernel_6884\2153832844.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')   #버전주의
#    서비스   순위                            타이틀            가수
# 0   지니    1                          Ditto      NewJeans
# 1   지니    2                            OMG      NewJeans
# 2   지니    3                       Hype boy      NewJeans
# 3   지니    4                        사건의 지평선   윤하 (YOUNHA)
# 4   지니    5  I Don't Think That I Like Her  Charlie Puth
# ..  ..  ...                            ...           ...
# 95  지니   96                strawberry moon      아이유 (IU)
# 96  지니   97                         Butter         방탄소년단
# 97  지니   98                       SNEAKERS     ITZY (있지)
# 98  지니   99                        나의 목소리로           김호중
# 99  지니  100                            Bad   Christopher
#
# [100 rows x 4 columns]

# %%
##########################################################
################       네이버웹툰      ####################


from selenium import webdriver          #웹브라우저 컨트롤
from bs4 import BeautifulSoup as bs     #읽어오느 웹페이지 정제
import pandas as pd                     #데이터분석 모듈

driver = webdriver.Chrome('chromedriver.exe')   #버전주의
url = 'https://comic.naver.com/webtoon/weekday'
driver.get(url)

txt=driver.page_source                  #이때 읽어온 데이터는 그냥 글자
html=bs(txt)
# Out:
# C:\Users\tlaru\AppData\Local\Temp\ipykernel_6884\3056501835.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')   #버전주의

# %%
len(html.select('a.title'))
# Out:
# 573

# %%
titles=html.select('a.title')

# %%
title=titles[0]
title
# Out:
# <a class="title" href="/webtoon/list?titleId=648419&amp;weekday=mon" onclick="nclk_v2(event,'thm*m.tit','','1')" title="뷰티풀 군바리">뷰티풀 군바리</a>

# %%
title_tmp = title.text
title_tmp
# Out:
# '뷰티풀 군바리'

# %%
title_list = []

for title in titles:
    title_name = title.text
    title_list.append(title_name)

pprint(title_list)
# Out:
# ['뷰티풀 군바리',
#  '퀘스트지상주의',
#  '신의 탑',
#  '장씨세가 호위무사',
#  '신화급 귀속 아이템을 손에 넣었다',
#  '윈드브레이커',
#  '팔이피플',
#  '소녀의 세계',
#  '버림받은 왕녀의 은밀한 침실',
#  '앵무살수',
#  '별난식당',
#  '똑 닮은 딸',
#  '퍼니게임',
#  '호랑신랑뎐',
#  '잔불의 기사',
#  '히어로메이커',
#  '북부 공작님을 유혹하겠습니다',
#  '물어보는 사이',
#  '꼬리잡기',
#  '신군',
#  '나 없는 단톡방',
#  '순정말고 순종',
#  '결혼생활 그림일기',
#  '루루라라 우리네 인생',
#  '만렙돌파',
#  '이별 후 사내 결혼',
#  '피폐물의 해피엔딩을 위하여',
#  '더블클릭',
#  '또다시, 계약 부부',
#  '파운더',
#  '수영만화일기',
#  '원하나',
#  '토마토가 돼라!',
#  '사이다걸',
#  '꿈의 기업',
#  '강남의 기사',
#  '랭커',
#  '오빠집이 비어서',
#  '사랑의 헌옷수거함',
#  '미니어처 생활백서',
#  '이제야 연애',
#  '악당과 악당이 만나면',
#  '인섹터',
#  '서브 남주가 파업하면 생기는 일',
#  '헬크래프트',
#  '우산 없는 애',
#  '다시쓰는 연애사',
#  '불청객',
#  '하루의 하루',
#  '아슈타르테',
#  '매지컬 급식:암살법사',
#  '메리의 불타는 행복회로',
#  '주작연애',
#  '입술이 예쁜 남자',
#  '라서드',
#  '백호랑',
#  '파견체',
#  '오늘의 비너스',
#  '집사, 주세요!',
#  '영앤리치가 아니야!',
#  '경비실에서 안내방송 드립니다',
#  '도깨비 부른다',
#  '최후의 금빛아이',
#  '굿바이 유교보이',
#  '모스크바의 여명',
#  '버그이터',
#  '너를 돌려차는 방법',
#  '지옥연애환담',
#  '모노마니아',
#  '악녀 18세 공략기',
# ...

# %%
##########################################################
################    네이버웹툰이쁘게   ####################


from selenium import webdriver          #웹브라우저 컨트롤
from bs4 import BeautifulSoup as bs     #읽어오느 웹페이지 정제
import pandas as pd                     #데이터분석 모듈

driver = webdriver.Chrome('chromedriver.exe')   #버전주의
url = 'https://comic.naver.com/webtoon/weekday'
driver.get(url)

txt=driver.page_source                  #이때 읽어온 데이터는 그냥 글자
html=bs(txt)

#title = html.select('a.title') select 문법

data = html.findAll('a',{'class':'title'})
titles = [title.text for title in titles]
pprint(titles)
# Out:
# C:\Users\tlaru\AppData\Local\Temp\ipykernel_6884\3115058103.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')   #버전주의
# ['뷰티풀 군바리',
#  '퀘스트지상주의',
#  '신의 탑',
#  '장씨세가 호위무사',
#  '신화급 귀속 아이템을 손에 넣었다',
#  '윈드브레이커',
#  '팔이피플',
#  '소녀의 세계',
#  '버림받은 왕녀의 은밀한 침실',
#  '앵무살수',
#  '별난식당',
#  '똑 닮은 딸',
#  '퍼니게임',
#  '호랑신랑뎐',
#  '잔불의 기사',
#  '히어로메이커',
#  '북부 공작님을 유혹하겠습니다',
#  '물어보는 사이',
#  '꼬리잡기',
#  '신군',
#  '나 없는 단톡방',
#  '순정말고 순종',
#  '결혼생활 그림일기',
#  '루루라라 우리네 인생',
#  '만렙돌파',
#  '이별 후 사내 결혼',
#  '피폐물의 해피엔딩을 위하여',
#  '더블클릭',
#  '또다시, 계약 부부',
#  '파운더',
#  '수영만화일기',
#  '원하나',
#  '토마토가 돼라!',
#  '사이다걸',
#  '꿈의 기업',
#  '강남의 기사',
#  '랭커',
#  '오빠집이 비어서',
#  '사랑의 헌옷수거함',
#  '미니어처 생활백서',
#  '이제야 연애',
#  '악당과 악당이 만나면',
#  '인섹터',
#  '서브 남주가 파업하면 생기는 일',
#  '헬크래프트',
#  '우산 없는 애',
#  '다시쓰는 연애사',
#  '불청객',
#  '하루의 하루',
#  '아슈타르테',
#  '매지컬 급식:암살법사',
#  '메리의 불타는 행복회로',
#  '주작연애',
#  '입술이 예쁜 남자',
#  '라서드',
#  '백호랑',
# ...

# %%
##########################################################
################    네이버날씨   ####################


import requests

txt = requests.get('https://weather.naver.com/')
html = bs(txt.text)

# %%
html.select('strong.current')[0].text.strip()
# Out:
# '현재 온도7.2°'

# %%
temp = html.select('strong.current')[0].text.strip()
temp[5:]
# Out:
# '7.2°'

# %%
import requests

txt = requests.get('https://weather.naver.com/')
html = bs(txt.text)

temp = html.select('strong.current')[0].text.strip()
temp[5:]
# Out:
# '7.2°'

# %%
##########################################################
################    비트코인   ####################


from selenium import webdriver        # 웹 브라우저 컨트롤 (크롬)
from bs4 import BeautifulSoup as bs   # 데이터 분석을 용이하게 정제
import pandas as pd                   # 데이터 분석 관련 모듈
from pprint import pprint 

driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
url = 'https://www.bithumb.com/react/'
driver.get(url)

txt = driver.page_source      # 이때 읽어온 데이터는 그냥 글자
html = bs(txt)


coins = html.findAll('strong', {'class':'MarketRow_sort-real__5zeND'})
coin = coins[0]

coins = [coin.text for coin in coins]

coins[1]
# Out:
# C:\Users\tlaru\AppData\Local\Temp\ipykernel_3868\249724349.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
# '31,068,000 원'

# %%
##########################################################
################    썸네일 자동으로 다운받기   #############

import requests         
from bs4 import BeautifulSoup as bs     #읽어오느 웹페이지 정제
import pandas as pd                     #데이터분석 모듈

url = 'https://comic.naver.com/webtoon/weekday'
txt = driver.page_source      # 이때 읽어온 데이터는 그냥 글자
html = bs(txt)

tlist= html.findAll('div',{'class':'col_inner'})
pprint(tlist)
# Out:
# [<div class="col_inner">
# <h4 class="mon"><span>월요 웹툰</span></h4>
# <ul>
# <li>
# <div class="thumb">
# <a href="/webtoon/list?titleId=648419&amp;weekday=mon" onclick="nclk_v2(event,'thm*m.img','','1')">
# <img alt="뷰티풀 군바리" height="107" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/648419/thumbnail/thumbnail_IMAG21_d9398229-cbfd-47dc-9208-0a6fb936f3a7.jpg" title="뷰티풀 군바리" width="83"/><span class="mask"></span>
# </a>
# </div>
# <a class="title" href="/webtoon/list?titleId=648419&amp;weekday=mon" onclick="nclk_v2(event,'thm*m.tit','','1')" title="뷰티풀 군바리">뷰티풀 군바리</a>
# </li>
# <li>
# <div class="thumb">
# <a href="/webtoon/list?titleId=783052&amp;weekday=mon" onclick="nclk_v2(event,'thm*m.img','','2')">
# ...

# %%
from urllib.request import urlretrieve  #파일 다운 로드

li_list = []

for data in tlist:
    #제목과 썸네일 영역 추출
    li_list.extend(data.findAll('li'))  #해당 부분을 찾아 병합

#pprint(li_list)

#썸네일과 제목 추출
for li in li_list:
    img = li.find('img')
    title = img['title']
    img_src = img['src']
    #print(title,img_src)
    #특수문자 제거
    title = re.sub('[^0-9a-zA-Zㄱ-힗]','',title)
    urlretrieve(img_src, title+'.jpg')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3868\3708011907.py in <module>
#      15     img_src = img['src']
#      16     #print(title,img_src)
# ---> 17     urlretrieve(img_src, title+'.jpg')
#
# c:\Users\tlaru\anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     247         # Handle temporary file setup.
#     248         if filename:
# --> 249             tfp = open(filename, 'wb')
#     250         else:
#     251             tfp = tempfile.NamedTemporaryFile(delete=False)
#
# OSError: [Errno 22] Invalid argument: '우리 집 고양이 보고 갈래?.jpg'
